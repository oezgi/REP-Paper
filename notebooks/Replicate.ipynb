# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
import numpy as np

# %% [markdown]
# # Replicability Study

# %% [markdown]
# ## Dataframes for Different Years and Leagues

# %% [markdown]
# ### Ligue 1

# %%
years = range(2014, 2024)
dataframes = {}

# %%
base_path = './match_database/ligue1/'

# %%
for year in years:
    file_path = f'{base_path}{year}.csv'  # Dynamically create file paths
    dataframes[f'df{year}'] = pd.read_csv(file_path)

# %%
df_ligue1_2014 = dataframes['df2014']
df_ligue1_2015 = dataframes['df2015']
df_ligue1_2016 = dataframes['df2016']
df_ligue1_2017 = dataframes['df2017']
df_ligue1_2018 = dataframes['df2018']
df_ligue1_2019 = dataframes['df2019']
df_ligue1_2020 = dataframes['df2020']
df_ligue1_2021 = dataframes['df2021']
df_ligue1_2022 = dataframes['df2022']
df_ligue1_2023 = dataframes['df2023']

# %% [markdown]
# ### La Liga

# %%
years = range(2014, 2024)
dataframes = {}

# %%
base_path = './match_database/la_liga/'

# %%
for year in years:
    file_path = f'{base_path}{year}.csv'  # Dynamically create file paths
    dataframes[f'df{year}'] = pd.read_csv(file_path)

# %%
df_laliga_2014 = dataframes['df2014']
df_laliga_2015 = dataframes['df2015']
df_laliga_2016 = dataframes['df2016']
df_laliga_2017 = dataframes['df2017']
df_laliga_2018 = dataframes['df2018']
df_laliga_2019 = dataframes['df2019']
df_laliga_2020 = dataframes['df2020']
df_laliga_2021 = dataframes['df2021']
df_laliga_2022 = dataframes['df2022']
df_laliga_2023 = dataframes['df2023']

# %% [markdown]
# ### Bundesliga

# %%
years = range(2014, 2024)  
dataframes = {}

# %%
base_path = './match_database/bundesliga/'

# %%
for year in years:
    file_path = f'{base_path}{year}.csv'  # Dynamically create file paths
    dataframes[f'df{year}'] = pd.read_csv(file_path)

# %%
df_bundesliga_2014 = dataframes['df2014']
df_bundesliga_2015 = dataframes['df2015']
df_bundesliga_2016 = dataframes['df2016']
df_bundesliga_2017 = dataframes['df2017']
df_bundesliga_2018 = dataframes['df2018']
df_bundesliga_2019 = dataframes['df2019']
df_bundesliga_2020 = dataframes['df2020']
df_bundesliga_2021 = dataframes['df2021']
df_bundesliga_2022 = dataframes['df2022']
df_bundesliga_2023 = dataframes['df2023']

# %% [markdown]
# ### EPL

# %%
years = range(2014, 2024) 
dataframes = {}

# %%
base_path = './match_database/epl/'

# %%
for year in years:
    file_path = f'{base_path}{year}.csv'  # Dynamically create file paths
    dataframes[f'df{year}'] = pd.read_csv(file_path)

# %%
df_epl_2014 = dataframes['df2014']
df_epl_2015 = dataframes['df2015']
df_epl_2016 = dataframes['df2016']
df_epl_2017 = dataframes['df2017']
df_epl_2018 = dataframes['df2018']
df_epl_2019 = dataframes['df2019']
df_epl_2020 = dataframes['df2020']
df_epl_2021 = dataframes['df2021']
df_epl_2022 = dataframes['df2022']
df_epl_2023 = dataframes['df2023']

# %% [markdown]
# ### Serie A

# %%
years = range(2014, 2024)  
dataframes = {}

# %%
base_path = './match_database/serieA/'

# %%
for year in years:
    file_path = f'{base_path}{year}.csv'  # Dynamically create file paths
    dataframes[f'df{year}'] = pd.read_csv(file_path)

# %%
df_seriea_2014 = dataframes['df2014']
df_seriea_2015 = dataframes['df2015']
df_seriea_2016 = dataframes['df2016']
df_seriea_2017 = dataframes['df2017']
df_seriea_2018 = dataframes['df2018']
df_seriea_2019 = dataframes['df2019']
df_seriea_2020 = dataframes['df2020']
df_seriea_2021 = dataframes['df2021']
df_seriea_2022 = dataframes['df2022']
df_seriea_2023 = dataframes['df2023']

# %% [markdown]
# ### RFPL

# %%
years = range(2014, 2024)
dataframes = {}

# %%
base_path = './match_database/rfpl/'

# %%
for year in years:
    file_path = f'{base_path}{year}.csv'  # Dynamically create file paths
    dataframes[f'df{year}'] = pd.read_csv(file_path)

# %%
df_rfpl_2014 = dataframes['df2014']
df_rfpl_2015 = dataframes['df2015']
df_rfpl_2016 = dataframes['df2016']
df_rfpl_2017 = dataframes['df2017']
df_rfpl_2018 = dataframes['df2018']
df_rfpl_2019 = dataframes['df2019']
df_rfpl_2020 = dataframes['df2020']
df_rfpl_2021 = dataframes['df2021']
df_rfpl_2022 = dataframes['df2022']
df_rfpl_2023 = dataframes['df2023']

# %% [markdown]
# ## Changing Statistical Tests for Assessing Differences Between Home and Away Matches

# %% [markdown]
# ### Using Paired t-Test instead of Wilcoxon

# %%
results_stat = pd.DataFrame()

# %% [markdown]
# ### Ligue 1

# %%
dataframes = {
    2014: df_ligue1_2014,
    2015: df_ligue1_2015,
    2016: df_ligue1_2016,
    2017: df_ligue1_2017,
    2018: df_ligue1_2018,
    2019: df_ligue1_2019,
    2020: df_ligue1_2020,
}

# %%
for season, df in dataframes.items():
    # Filter data for home and away games
    home_pts = df[df['h_a'] == 'h']['pts']
    away_pts = df[df['h_a'] == 'a']['pts']
    home_xpts = df[df['h_a'] == 'h']['xpts']
    away_xpts = df[df['h_a'] == 'a']['xpts']
    home_xg = df[df['h_a'] == 'h']['xG']
    away_xg = df[df['h_a'] == 'a']['xG']
    
    # Perform Paired t-Test
    ttest_result = stats.ttest_rel(home_pts, away_pts)
    ttest_xpts = stats.ttest_rel(home_xpts, away_xpts)
    ttest_xg = stats.ttest_rel(home_xg, away_xg)
    
    # Store results in a dictionary
    result = {
        "league": "Ligue_1",
        "season": season,
        "ttest_result": ttest_result.statistic,
        "ttest_result-pvalue": ttest_result.pvalue,
        "ttest-xPoints": ttest_xpts.statistic,
        "ttest-xPoints-pvalue": ttest_xpts.pvalue,
        "ttest-xG": ttest_xg.statistic,
        "ttest-xG-pvalue": ttest_xg.pvalue,
    }
    
    # Append the result to the results list
    results_stat = pd.concat([results_stat, pd.DataFrame([result])], ignore_index=True)

# %%
results_stat
# Out:
#     league  season  ttest_result  ttest_result-pvalue  ttest-xPoints  \
# 0  Ligue_1    2014      5.894396         8.319528e-09       8.900834
# 1  Ligue_1    2015      4.439287         1.185318e-05      10.232121
# 2  Ligue_1    2016      7.485472         5.038320e-13       9.969743
# 3  Ligue_1    2017      5.681467         2.665015e-08       9.077650
# 4  Ligue_1    2018      5.301624         1.953816e-07       8.264811
# 5  Ligue_1    2019      6.167353         2.440138e-09       6.982315
# 6  Ligue_1    2020     -0.086525         9.310944e-01       2.790627
#
#    ttest-xPoints-pvalue  ttest-xG  ttest-xG-pvalue
# 0          2.322085e-17  6.346558     6.291324e-10
# 1          7.348729e-22  7.471841     5.514790e-13
# 2          6.049650e-21  7.042312     8.947314e-12
# 3          6.166917e-18  6.926051     1.863199e-11
# 4          2.380272e-15  7.056480     8.177240e-12
# 5          2.137746e-11  5.642696     4.121886e-08
# 6          5.526608e-03  2.735234     6.526492e-03

# %% [markdown]
# ### La Liga

# %%
dataframes = {
    2014: df_laliga_2014,
    2015: df_laliga_2015,
    2016: df_laliga_2016,
    2017: df_laliga_2017,
    2018: df_laliga_2018,
    2019: df_laliga_2019,
    2020: df_laliga_2020,
}

# %%
for season, df in dataframes.items():
    # Filter data for home and away games
    home_pts = df[df['h_a'] == 'h']['pts']
    away_pts = df[df['h_a'] == 'a']['pts']
    home_xpts = df[df['h_a'] == 'h']['xpts']
    away_xpts = df[df['h_a'] == 'a']['xpts']
    home_xg = df[df['h_a'] == 'h']['xG']
    away_xg = df[df['h_a'] == 'a']['xG']
    
     # Perform Paired t-Test
    ttest_result = stats.ttest_rel(home_pts, away_pts)
    ttest_xpts = stats.ttest_rel(home_xpts, away_xpts)
    ttest_xg = stats.ttest_rel(home_xg, away_xg)
    
    # Store results in a dictionary
    result = {
        "league": "La_liga",
        "season": season,
        "ttest_result": ttest_result.statistic,
        "ttest_result-pvalue": ttest_result.pvalue,
        "ttest-xPoints": ttest_xpts.statistic,
        "ttest-xPoints-pvalue": ttest_xpts.pvalue,
        "ttest-xG": ttest_xg.statistic,
        "ttest-xG-pvalue": ttest_xg.pvalue,
    }
    
    # Append the result to the results list
    results_stat = pd.concat([results_stat, pd.DataFrame([result])], ignore_index=True)

# %% [markdown]
# ### EPL

# %%
dataframes = {
    2014: df_epl_2014,
    2015: df_epl_2015,
    2016: df_epl_2016,
    2017: df_epl_2017,
    2018: df_epl_2018,
    2019: df_epl_2019,
    2020: df_epl_2020,
}

# %%
for season, df in dataframes.items():
    # Filter data for home and away games
    home_pts = df[df['h_a'] == 'h']['pts']
    away_pts = df[df['h_a'] == 'a']['pts']
    home_xpts = df[df['h_a'] == 'h']['xpts']
    away_xpts = df[df['h_a'] == 'a']['xpts']
    home_xg = df[df['h_a'] == 'h']['xG']
    away_xg = df[df['h_a'] == 'a']['xG']
    
    # Perform Paired t-Test
    ttest_result = stats.ttest_rel(home_pts, away_pts)
    ttest_xpts = stats.ttest_rel(home_xpts, away_xpts)
    ttest_xg = stats.ttest_rel(home_xg, away_xg)
    
    # Store results in a dictionary
    result = {
        "league": "EPL",
        "season": season,
        "ttest_result": ttest_result.statistic,
        "ttest_result-pvalue": ttest_result.pvalue,
        "ttest-xPoints": ttest_xpts.statistic,
        "ttest-xPoints-pvalue": ttest_xpts.pvalue,
        "ttest-xG": ttest_xg.statistic,
        "ttest-xG-pvalue": ttest_xg.pvalue,
    }
    
    # Append the result to the results list
    results_stat = pd.concat([results_stat, pd.DataFrame([result])], ignore_index=True)

# %% [markdown]
# ### Bundesliga

# %%
dataframes = {
    2014: df_bundesliga_2014,
    2015: df_bundesliga_2015,
    2016: df_bundesliga_2016,
    2017: df_bundesliga_2017,
    2018: df_bundesliga_2018,
    2019: df_bundesliga_2019,
    2020: df_bundesliga_2020,
}

# %%
for season, df in dataframes.items():
    # Filter data for home and away games
    home_pts = df[df['h_a'] == 'h']['pts']
    away_pts = df[df['h_a'] == 'a']['pts']
    home_xpts = df[df['h_a'] == 'h']['xpts']
    away_xpts = df[df['h_a'] == 'a']['xpts']
    home_xg = df[df['h_a'] == 'h']['xG']
    away_xg = df[df['h_a'] == 'a']['xG']
    
     # Perform Paired t-Test
    ttest_result = stats.ttest_rel(home_pts, away_pts)
    ttest_xpts = stats.ttest_rel(home_xpts, away_xpts)
    ttest_xg = stats.ttest_rel(home_xg, away_xg)
    
    # Store results in a dictionary
    result = {
        "league": "Bundesliga",
        "season": season,
        "ttest_result": ttest_result.statistic,
        "ttest_result-pvalue": ttest_result.pvalue,
        "ttest-xPoints": ttest_xpts.statistic,
        "ttest-xPoints-pvalue": ttest_xpts.pvalue,
        "ttest-xG": ttest_xg.statistic,
        "ttest-xG-pvalue": ttest_xg.pvalue,
    }
    
    # Append the result to the results list
    results_stat = pd.concat([results_stat, pd.DataFrame([result])], ignore_index=True)

# %% [markdown]
# ### Serie A

# %%
dataframes = {
    2014: df_seriea_2014,
    2015: df_seriea_2015,
    2016: df_seriea_2016,
    2017: df_seriea_2017,
    2018: df_seriea_2018,
    2019: df_seriea_2019,
    2020: df_seriea_2020,
}

# %%
for season, df in dataframes.items():
    # Filter data for home and away games
    home_pts = df[df['h_a'] == 'h']['pts']
    away_pts = df[df['h_a'] == 'a']['pts']
    home_xpts = df[df['h_a'] == 'h']['xpts']
    away_xpts = df[df['h_a'] == 'a']['xpts']
    home_xg = df[df['h_a'] == 'h']['xG']
    away_xg = df[df['h_a'] == 'a']['xG']
    
     # Perform Paired t-Test
    ttest_result = stats.ttest_rel(home_pts, away_pts)
    ttest_xpts = stats.ttest_rel(home_xpts, away_xpts)
    ttest_xg = stats.ttest_rel(home_xg, away_xg)
    
    # Store results in a dictionary
    result = {
        "league": "Serie_A",
        "season": season,
        "ttest_result": ttest_result.statistic,
        "ttest_result-pvalue": ttest_result.pvalue,
        "ttest-xPoints": ttest_xpts.statistic,
        "ttest-xPoints-pvalue": ttest_xpts.pvalue,
        "ttest-xG": ttest_xg.statistic,
        "ttest-xG-pvalue": ttest_xg.pvalue,
    }
    
    # Append the result to the results list
    results_stat = pd.concat([results_stat, pd.DataFrame([result])], ignore_index=True)

# %% [markdown]
# ### RFPL

# %%
dataframes = {
    2014: df_rfpl_2014,
    2015: df_rfpl_2015,
    2016: df_rfpl_2016,
    2017: df_rfpl_2017,
    2018: df_rfpl_2018,
    2019: df_rfpl_2019,
    2020: df_rfpl_2020,
}

# %%
for season, df in dataframes.items():
    # Filter data for home and away games
    home_pts = df[df['h_a'] == 'h']['pts']
    away_pts = df[df['h_a'] == 'a']['pts']
    home_xpts = df[df['h_a'] == 'h']['xpts']
    away_xpts = df[df['h_a'] == 'a']['xpts']
    home_xg = df[df['h_a'] == 'h']['xG']
    away_xg = df[df['h_a'] == 'a']['xG']
    
     # Perform Paired t-Test
    ttest_result = stats.ttest_rel(home_pts, away_pts)
    ttest_xpts = stats.ttest_rel(home_xpts, away_xpts)
    ttest_xg = stats.ttest_rel(home_xg, away_xg)
    
    # Store results in a dictionary
    result = {
        "league": "RFPL",
        "season": season,
        "ttest_result": ttest_result.statistic,
        "ttest_result-pvalue": ttest_result.pvalue,
        "ttest-xPoints": ttest_xpts.statistic,
        "ttest-xPoints-pvalue": ttest_xpts.pvalue,
        "ttest-xG": ttest_xg.statistic,
        "ttest-xG-pvalue": ttest_xg.pvalue,
    }
    
    # Append the result to the results list
    results_stat = pd.concat([results_stat, pd.DataFrame([result])], ignore_index=True)

# %%
def highlight_pvalues(val):
    try:
        if pd.notna(val) and float(val) > 0.05:
            return 'color: red;'  # Highlight significant p-values in red
    except ValueError:
        pass
    return ''

# %%
styled_results_stat = results_stat.style.applymap(highlight_pvalues, subset=[
    'ttest_result-pvalue', 'ttest-xPoints-pvalue', 'ttest-xG-pvalue'
])
# Out:
# C:\Users\ezgi\AppData\Local\Temp\ipykernel_54868\1157507152.py:1: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   styled_results_stat = results_stat.style.applymap(highlight_pvalues, subset=[

# %%
styled_results_stat
# Out:
# <style type="text/css">
# #T_d5a8d_row6_col3, #T_d5a8d_row20_col3, #T_d5a8d_row26_col3, #T_d5a8d_row33_col3, #T_d5a8d_row40_col3 {
#   color: red;
# }
# </style>
# <table id="T_d5a8d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d5a8d_level0_col0" class="col_heading level0 col0" >league</th>
#       <th id="T_d5a8d_level0_col1" class="col_heading level0 col1" >season</th>
#       <th id="T_d5a8d_level0_col2" class="col_heading level0 col2" >ttest_result</th>
#       <th id="T_d5a8d_level0_col3" class="col_heading level0 col3" >ttest_result-pvalue</th>
#       <th id="T_d5a8d_level0_col4" class="col_heading level0 col4" >ttest-xPoints</th>
#       <th id="T_d5a8d_level0_col5" class="col_heading level0 col5" >ttest-xPoints-pvalue</th>
#       <th id="T_d5a8d_level0_col6" class="col_heading level0 col6" >ttest-xG</th>
#       <th id="T_d5a8d_level0_col7" class="col_heading level0 col7" >ttest-xG-pvalue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d5a8d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d5a8d_row0_col0" class="data row0 col0" >Ligue_1</td>
#       <td id="T_d5a8d_row0_col1" class="data row0 col1" >2014</td>
#       <td id="T_d5a8d_row0_col2" class="data row0 col2" >5.894396</td>
#       <td id="T_d5a8d_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_d5a8d_row0_col4" class="data row0 col4" >8.900834</td>
#       <td id="T_d5a8d_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_d5a8d_row0_col6" class="data row0 col6" >6.346558</td>
#       <td id="T_d5a8d_row0_col7" class="data row0 col7" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d5a8d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d5a8d_row1_col0" class="data row1 col0" >Ligue_1</td>
#       <td id="T_d5a8d_row1_col1" class="data row1 col1" >2015</td>
#       <td id="T_d5a8d_row1_col2" class="data row1 col2" >4.439287</td>
#       <td id="T_d5a8d_row1_col3" class="data row1 col3" >0.000012</td>
#       <td id="T_d5a8d_row1_col4" class="data row1 col4" >10.232121</td>
#       <td id="T_d5a8d_row1_col5" class="data row1 col5" >0.000000</td>
#       <td id="T_d5a8d_row1_col6" class="data row1 col6" >7.471841</td>
#       <td id="T_d5a8d_row1_col7" class="data row1 col7" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d5a8d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d5a8d_row2_col0" class="data row2 col0" >Ligue_1</td>
#       <td id="T_d5a8d_row2_col1" class="data row2 col1" >2016</td>
#       <td id="T_d5a8d_row2_col2" class="data row2 col2" >7.485472</td>
#       <td id="T_d5a8d_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_d5a8d_row2_col4" class="data row2 col4" >9.969743</td>
#       <td id="T_d5a8d_row2_col5" class="data row2 col5" >0.000000</td>
#       <td id="T_d5a8d_row2_col6" class="data row2 col6" >7.042312</td>
#       <td id="T_d5a8d_row2_col7" class="data row2 col7" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d5a8d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d5a8d_row3_col0" class="data row3 col0" >Ligue_1</td>
#       <td id="T_d5a8d_row3_col1" class="data row3 col1" >2017</td>
#       <td id="T_d5a8d_row3_col2" class="data row3 col2" >5.681467</td>
#       <td id="T_d5a8d_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_d5a8d_row3_col4" class="data row3 col4" >9.077650</td>
#       <td id="T_d5a8d_row3_col5" class="data row3 col5" >0.000000</td>
#       <td id="T_d5a8d_row3_col6" class="data row3 col6" >6.926051</td>
#       <td id="T_d5a8d_row3_col7" class="data row3 col7" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d5a8d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d5a8d_row4_col0" class="data row4 col0" >Ligue_1</td>
#       <td id="T_d5a8d_row4_col1" class="data row4 col1" >2018</td>
#       <td id="T_d5a8d_row4_col2" class="data row4 col2" >5.301624</td>
#       <td id="T_d5a8d_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_d5a8d_row4_col4" class="data row4 col4" >8.264811</td>
#       <td id="T_d5a8d_row4_col5" class="data row4 col5" >0.000000</td>
#       <td id="T_d5a8d_row4_col6" class="data row4 col6" >7.056480</td>
#       <td id="T_d5a8d_row4_col7" class="data row4 col7" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d5a8d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d5a8d_row5_col0" class="data row5 col0" >Ligue_1</td>
#       <td id="T_d5a8d_row5_col1" class="data row5 col1" >2019</td>
#       <td id="T_d5a8d_row5_col2" class="data row5 col2" >6.167353</td>
#       <td id="T_d5a8d_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_d5a8d_row5_col4" class="data row5 col4" >6.982315</td>
#       <td id="T_d5a8d_row5_col5" class="data row5 col5" >0.000000</td>
#       <td id="T_d5a8d_row5_col6" class="data row5 col6" >5.642696</td>
#       <td id="T_d5a8d_row5_col7" class="data row5 col7" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d5a8d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d5a8d_row6_col0" class="data row6 col0" >Ligue_1</td>
#       <td id="T_d5a8d_row6_col1" class="data row6 col1" >2020</td>
#       <td id="T_d5a8d_row6_col2" class="data row6 col2" >-0.086525</td>
#       <td id="T_d5a8d_row6_col3" class="data row6 col3" >0.931094</td>
#       <td id="T_d5a8d_row6_col4" class="data row6 col4" >2.790627</td>
#       <td id="T_d5a8d_row6_col5" class="data row6 col5" >0.005527</td>
#       <td id="T_d5a8d_row6_col6" class="data row6 col6" >2.735234</td>
#       <td id="T_d5a8d_row6_col7" class="data row6 col7" >0.006526</td>
#     </tr>
#     <tr>
#       <th id="T_d5a8d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d5a8d_row7_col0" class="data row7 col0" >La_liga</td>
#       <td id="T_d5a8d_row7_col1" class="data row7 col1" >2014</td>
#       <td id="T_d5a8d_row7_col2" class="data row7 col2" >4.826327</td>
#       <td id="T_d5a8d_row7_col3" class="data row7 col3" >0.000002</td>
#       <td id="T_d5a8d_row7_col4" class="data row7 col4" >10.144456</td>
#       <td id="T_d5a8d_row7_col5" class="data row7 col5" >0.000000</td>
#       <td id="T_d5a8d_row7_col6" class="data row7 col6" >7.462015</td>
#       <td id="T_d5a8d_row7_col7" class="data row7 col7" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d5a8d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d5a8d_row8_col0" class="data row8 col0" >La_liga</td>
#       <td id="T_d5a8d_row8_col1" class="data row8 col1" >2015</td>
#       <td id="T_d5a8d_row8_col2" class="data row8 col2" >6.752000</td>
#       <td id="T_d5a8d_row8_col3" class="data row8 col3" >0.000000</td>
#       <td id="T_d5a8d_row8_col4" class="data row8 col4" >8.710303</td>
#       <td id="T_d5a8d_row8_col5" class="data row8 col5" >0.000000</td>
#       <td id="T_d5a8d_row8_col6" class="data row8 col6" >7.275050</td>
#       <td id="T_d5a8d_row8_col7" class="data row8 col7" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d5a8d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d5a8d_row9_col0" class="data row9 col0" >La_liga</td>
#       <td id="T_d5a8d_row9_col1" class="data row9 col1" >2016</td>
#       <td id="T_d5a8d_row9_col2" class="data row9 col2" >6.146814</td>
#       <td id="T_d5a8d_row9_col3" class="data row9 col3" >0.000000</td>
#       <td id="T_d5a8d_row9_col4" class="data row9 col4" >10.307581</td>
#       <td id="T_d5a8d_row9_col5" class="data row9 col5" >0.000000</td>
#       <td id="T_d5a8d_row9_col6" class="data row9 col6" >7.354092</td>
#       <td id="T_d5a8d_row9_col7" class="data row9 col7" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d5a8d_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_d5a8d_row10_col0" class="data row10 col0" >La_liga</td>
#       <td id="T_d5a8d_row10_col1" class="data row10 col1" >2017</td>
#       <td id="T_d5a8d_row10_col2" class="data row10 col2" >5.491981</td>
#       <td id="T_d5a8d_row10_col3" class="data row10 col3" >0.000000</td>
#       <td id="T_d5a8d_row10_col4" class="data row10 col4" >11.757590</td>
#       <td id="T_d5

# %% [markdown]
# Since the analysis spans from 2014 to 2020, the lack of a significant difference in 2020 (or 2019, either way, during the COVID season) suggests that home advantage might have diminished or disappeared entirely during the COVID-19 pandemic due to the absence of fans and altered match conditions (e.g., no crowds, travel restrictions). This result supports the idea that:
# **Home advantage is influenced by external factors like crowd support, and the absence of these factors during COVID nullified the advantage.**

# %% [markdown]
# ## Post-COVID Seasons as a Variability Factor

# %% [markdown]
# In this replicability analysis, we aim to assess the impact of the post-COVID seasons (2021 onward) as a potential variability factor in understanding home advantage in football. The COVID-19 pandemic created a unique natural experiment in sports, where matches were played in empty stadiums, effectively removing one of the critical elements of home advantage: crowd support. This provided a rare opportunity to isolate the influence of environmental and psychological factors on team performance.
#
# However, with the return of fans to stadiums in subsequent seasons, an important question arises: **Did home-field advantage return to pre-COVID levels, or has the dynamic shifted permanently?** This variability factor—performance in post-COVID seasons—will allow us to test the robustness and generalizability of the original study's conclusions.

# %% [markdown]
# ### Table with bar charts to visualize and investigate a possible effect of COVID on home advantage

# %% [markdown]
# This chart visualizes the difference between home and away performance for various leagues and seasons based on both actual points (DIFF_POINTS_HOMEAWAY) and expected points (DIFF_XPOINTS_HOMEAWAY).

# %%
df = pd.read_csv("database.csv")

# %%
diff_results = pd.DataFrame({
    "LEAGUE": df["ligue"],  # Keep the league column
    "YEAR": df["season"],      # Keep the year column
    "DIFF_POINTS_HOMEAWAY": df["sum_pts_h"] - df["sum_pts_a"],  # Calculate points difference
    "DIFF_XPOINTS_HOMEAWAY": (df["sum_xpts_h"] - df["sum_xpts_a"]).round(0).astype(int)  # Calculate xpoints difference
})

# %%
styled_df = diff_results.style.bar(
    subset=["DIFF_POINTS_HOMEAWAY", "DIFF_XPOINTS_HOMEAWAY"], 
    color=['lightcoral', 'mediumseagreen'], 
    align='zero'  # Aligns negative bars to the left
)
styled_df
# Out:
# <style type="text/css">
# #T_b1b49_row0_col2, #T_b1b49_row42_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, mediumseagreen 50.0%, mediumseagreen 90.7%, transparent 90.7%);
# }
# #T_b1b49_row0_col3, #T_b1b49_row3_col2, #T_b1b49_row40_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, mediumseagreen 50.0%, mediumseagreen 86.0%, transparent 86.0%);
# }
# #T_b1b49_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, mediumseagreen 50.0%, mediumseagreen 77.9%, transparent 77.9%);
# }
# #T_b1b49_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, mediumseagreen 50.0%, mediumseagreen 90.5%, transparent 90.5%);
# }
# #T_b1b49_row2_col2, #T_b1b49_row13_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, mediumseagreen 50.0%, mediumseagreen 100.0%, transparent 100.0%);
# }
# #T_b1b49_row2_col3, #T_b1b49_row12_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, mediumseagreen 50.0%, mediumseagreen 91.3%, transparent 91.3%);
# }
# #T_b1b49_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, mediumseagreen 50.0%, mediumseagreen 87.5%, transparent 87.5%);
# }
# #T_b1b49_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, mediumseagreen 50.0%, mediumseagreen 83.7%, transparent 83.7%);
# }
# #T_b1b49_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, mediumseagreen 50.0%, mediumseagreen 85.8%, transparent 85.8%);
# }
# #T_b1b49_row5_col2, #T_b1b49_row38_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, mediumseagreen 50.0%, mediumseagreen 84.3%, transparent 84.3%);
# }
# #T_b1b49_row5_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, mediumseagreen 50.0%, mediumseagreen 75.4%, transparent 75.4%);
# }
# #T_b1b49_row6_col2, #T_b1b49_row55_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 49.4%, lightcoral 49.4%, lightcoral 50.0%, transparent 50.0%);
# }
# #T_b1b49_row6_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, mediumseagreen 50.0%, mediumseagreen 62.9%, transparent 62.9%);
# }
# #T_b1b49_row7_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, mediumseagreen 50.0%, mediumseagreen 76.7%, transparent 76.7%);
# }
# #T_b1b49_row7_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, mediumseagreen 50.0%, mediumseagreen 80.7%, transparent 80.7%);
# }
# #T_b1b49_row8_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, mediumseagreen 50.0%, mediumseagreen 72.1%, transparent 72.1%);
# }
# #T_b1b49_row8_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, mediumseagreen 50.0%, mediumseagreen 69.9%, transparent 69.9%);
# }
# #T_b1b49_row9_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, mediumseagreen 50.0%, mediumseagreen 58.7%, transparent 58.7%);
# }
# #T_b1b49_row9_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, mediumseagreen 50.0%, mediumseagreen 82.8%, transparent 82.8%);
# }
# #T_b1b49_row10_col2, #T_b1b49_row24_col2, #T_b1b49_row37_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, mediumseagreen 50.0%, mediumseagreen 80.8%, transparent 80.8%);
# }
# #T_b1b49_row10_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, mediumseagreen 50.0%, mediumseagreen 92.6%, transparent 92.6%);
# }
# #T_b1b49_row11_col2, #T_b1b49_row22_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, mediumseagreen 50.0%, mediumseagreen 95.3%, transparent 95.3%);
# }
# #T_b1b49_row11_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, mediumseagreen 50.0%, mediumseagreen 86.7%, transparent 86.7%);
# }
# #T_b1b49_row12_col3, #T_b1b49_row28_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, mediumseagreen 50.0%, mediumseagreen 93.6%, transparent 93.6%);
# }
# #T_b1b49_row13_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, mediumseagreen 50.0%, mediumseagreen 87.2%, transparent 87.2%);
# }
# #T_b1b49_row14_col2, #T_b1b49_row30_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, mediumseagreen 50.0%, mediumseagreen 88.4%, transparent 88.4%);
# }
# #T_b1b49_row14_col3, #T_b1b49_row29_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, mediumseagreen 50.0%, mediumseagreen 94.3%, transparent 94.3%);
# }
# #T_b1b49_row15_col2, #T_b1b49_row18_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, mediumseagreen 50.0%, mediumseagreen 92.4%, transparent 92.4%);
# }
# #T_b1b49_row15_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, mediumseagreen 50.0%, mediumseagreen 89.8%, transparent 89.8%);
# }
# #T_b1b49_row16_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, mediumseagreen 50.0%, mediumseagreen 76.2%, transparent 76.2%);
# }
# #T_b1b49_row16_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, mediumseagreen 50.0%, mediumseagreen 71.8%, transparent 71.8%);
# }
# #T_b1b49_row17_col2, #T_b1b49_row19_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, mediumseagreen 50.0%, mediumseagreen 85.5%, transparent 85.5%);
# }
# #T_b1b49_row17_col3, #T_b1b49_row42_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, mediumseagreen 50.0%, mediumseagreen 84.1%, transparent 84.1%);
# }
# #T_b1b49_row18_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, mediumseagreen 50.0%, mediumseagreen 98.9%, transparent 98.9%);
# }
# #T_b1b49_row19_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, mediumseagreen 50.0%, mediumseagreen 97.2%, transparent 97.2%);
# }
# #T_b1b49_row20_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, mediumseagreen 50.0%, mediumseagreen 83.1%, transparent 83.1%);
# }
# #T_b1b49_row20_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, mediumseagreen 50.0%, mediumseagreen 93.4%, transparent 93.4%);
# }
# #T_b1b49_row21_col2, #T_b1b49_row58_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, mediumseagreen 50.0%, mediumseagreen 73.8%, transparent 73.8%);
# }
# #T_b1b49_row21_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, mediumseagreen 50.0%, mediumseagreen 77.8%, transparent 77.8%);
# }
# #T_b1b49_row22_col3, #T_b1b49_row25_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, mediumseagreen 50.0%, mediumseagreen 82.6%, transparent 82.6%);
# }
# #T_b1b49_row23_col2, #T_b1b49_row41_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, mediumseagreen 50.0%, mediumseagreen 87.8%, transparent 87.8%);
# }
# #T_b1b49_row23_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, mediumseagreen 50.0%, mediumseagreen 87.3%, transparent 87.3%);
# }
# #T_b1b49_row24_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, mediumseagreen 50.0%, mediumseagreen 78.0%, transparent 78.0%);
# }
# #T_b1b49_row25_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, mediumseagreen 50.0%, mediumseagreen 72.2%, transparent 72.2%);
# }
# #T_b1b49_row26_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 44.8%, lightcoral 44.8%, lightcoral 50.0%, transparent 50.0%);
# }
# #T_b1b49_row26_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, mediumseagreen 50.0%, mediumseagreen 60.2%, transparent 60.2%);
# }
# #T_b1b49_row27_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, mediumseagreen 50.0%, mediumseagreen 69.8%, transparent 69.8%);
# }
# #T_b1b49_row27_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, mediumseagreen 50.0%, mediumseagreen 78.2%, t

# %% [markdown]
# From this chart, we can see that home advantage diminished significantly during the COVID season, possibly due to the absence of crowds. While crowds have returned post-COVID, the full restoration of home advantage is uneven across leagues, with some (like the EPL) showing stronger recovery than others (like Ligue 1, Serie A, and Bundesliga). This variability highlights the long-term impact of the pandemic on football dynamics, suggesting a lasting shift in how home advantage operates in some leagues.

# %% [markdown]
# ### Plot of evolution of mean gained points (per match)

# %%
leagues = df['ligue'].unique()
leagues
# Out:
# array(['Ligue1', 'La Liga', 'EPL', 'Bundesliga', 'Serie A', 'RFPL'],
#       dtype=object)

# %%
for i, league in enumerate(leagues):
    league_data = df[df['ligue'] == league]  # Filter for league
    plt.plot(league_data['season'], league_data['avg_pts_h'], marker='o', label='result')
    plt.plot(league_data['season'], league_data['avg_xpts_h'], marker='o', label='xPoints')
    plt.plot(league_data['season'], league_data['avg_pts_a'], marker='o', label='result_away')
    plt.plot(league_data['season'], league_data['avg_xpts_a'], marker='o', label='xPointsAway', color='red')
    plt.xlabel('seasons')
    plt.ylabel('mean gained points per match')
    plt.title(league)
    plt.legend()
    plt.show()

# %% [markdown]
# Across all leagues, the absence of crowds during the COVID season significantly reduced or nullified home advantage. Home teams scored fewer points, while away teams improved, highlighting the importance of crowd support and environmental factors in football dynamics.
# Post-COVID, most leagues show a partial recovery in home advantage with the return of crowds, but only the English Premier League appears to have fully regained its pre-COVID dynamics. Other leagues, like Ligue 1, Bundesliga, and Serie A, show a lasting reduction in the home-field advantage, suggesting a new normal where the gap between home and away performances is narrower than before.

# %% [markdown]
# ### Statistical Analysis of Home Advantage

# %% [markdown]
# By performing **Wilcoxon Signed-Rank** tests and calculating **Cohen’s d effect** sizes, we aim to quantify the differences between home and away performances both before, during, and after the pandemic.
# This analysis investigates:
# 1. **Statistical Significance:** Using Wilcoxon p-values to determine whether differences in metrics such as points (pts), expected points (xPoints), and expected goals (xG) between home and away teams are significant.
# 2. **Effect Sizes:** Using Cohen’s d to measure the magnitude of these differences and assess the practical impact of home advantage.

# %%
results_stat = pd.DataFrame()

# %% [markdown]
# #### Ligue 1

# %%
dataframes = {
    # Ligue 1
    2014: df_ligue1_2014,
    2015: df_ligue1_2015,
    2016: df_ligue1_2016,
    2017: df_ligue1_2017,
    2018: df_ligue1_2018,
    2019: df_ligue1_2019,
    2020: df_ligue1_2020,
    2021: df_ligue1_2021,
    2022: df_ligue1_2022,
    2023: df_ligue1_2023,
}

# %%
for season, df in dataframes.items():
    # Filter data for home and away games
    home_pts = df[df['h_a'] == 'h']['pts']
    away_pts = df[df['h_a'] == 'a']['pts']
    home_xpts = df[df['h_a'] == 'h']['xpts']
    away_xpts = df[df['h_a'] == 'a']['xpts']
    home_xg = df[df['h_a'] == 'h']['xG']
    away_xg = df[df['h_a'] == 'a']['xG']
    
    # Perform Wilcoxon Signed-Rank tests
    wilco_result = stats.wilcoxon(home_pts, away_pts, alternative='two-sided')
    wilco_xpts = stats.wilcoxon(home_xpts, away_xpts, alternative='two-sided')
    wilco_xg = stats.wilcoxon(home_xg, away_xg, alternative='two-sided')
    
    # Calculate Cohen's d for each metric
    cohend_result = (home_pts.mean() - away_pts.mean()) / np.sqrt((home_pts.std() ** 2 + away_pts.std() ** 2) / 2)
    cohend_xpts = (home_xpts.mean() - away_xpts.mean()) / np.sqrt((home_xpts.std() ** 2 + away_xpts.std() ** 2) / 2)
    cohend_xg = (home_xg.mean() - away_xg.mean()) / np.sqrt((home_xg.std() ** 2 + away_xg.std() ** 2) / 2)
    
    # Store results in a dictionary
    result = {
        "league": "Ligue_1",
        "season": season,
        "wilco-result": wilco_result.statistic,
        "wilco-result-pvalue": wilco_result.pvalue,
        "result-cohend": cohend_result,
        "wilco-xPoints": wilco_xpts.statistic,
        "wilco-xPoints-pvalue": wilco_xpts.pvalue,
        "xPoints-cohend": cohend_xpts,
        "wilco-xG": wilco_xg.statistic,
        "wilco-xG-pvalue": wilco_xg.pvalue,
        "xG-cohend": cohend_xg,
    }
    
    # Append the result to the results list
    results_stat = pd.concat([results_stat, pd.DataFrame([result])], ignore_index=True)

# %% [markdown]
# #### La Liga

# %%
dataframes = {
    # La Liga
    2014: df_laliga_2014,
    2015: df_laliga_2015,
    2016: df_laliga_2016,
    2017: df_laliga_2017,
    2018: df_laliga_2018,
    2019: df_laliga_2019,
    2020: df_laliga_2020,
    2021: df_laliga_2021,
    2022: df_laliga_2022,
    2023: df_laliga_2023,
}

# %%
for season, df in dataframes.items():
    # Filter data for home and away games
    home_pts = df[df['h_a'] == 'h']['pts']
    away_pts = df[df['h_a'] == 'a']['pts']
    home_xpts = df[df['h_a'] == 'h']['xpts']
    away_xpts = df[df['h_a'] == 'a']['xpts']
    home_xg = df[df['h_a'] == 'h']['xG']
    away_xg = df[df['h_a'] == 'a']['xG']
    
    # Perform Wilcoxon Signed-Rank tests
    wilco_result = stats.wilcoxon(home_pts, away_pts, alternative='two-sided')
    wilco_xpts = stats.wilcoxon(home_xpts, away_xpts, alternative='two-sided')
    wilco_xg = stats.wilcoxon(home_xg, away_xg, alternative='two-sided')
    
    # Calculate Cohen's d for each metric
    cohend_result = (home_pts.mean() - away_pts.mean()) / np.sqrt((home_pts.std() ** 2 + away_pts.std() ** 2) / 2)
    cohend_xpts = (home_xpts.mean() - away_xpts.mean()) / np.sqrt((home_xpts.std() ** 2 + away_xpts.std() ** 2) / 2)
    cohend_xg = (home_xg.mean() - away_xg.mean()) / np.sqrt((home_xg.std() ** 2 + away_xg.std() ** 2) / 2)
    
    # Store results in a dictionary
    result = {
        "league": "La_Liga",
        "season": season,
        "wilco-result": wilco_result.statistic,
        "wilco-result-pvalue": wilco_result.pvalue,
        "result-cohend": cohend_result,
        "wilco-xPoints": wilco_xpts.statistic,
        "wilco-xPoints-pvalue": wilco_xpts.pvalue,
        "xPoints-cohend": cohend_xpts,
        "wilco-xG": wilco_xg.statistic,
        "wilco-xG-pvalue": wilco_xg.pvalue,
        "xG-cohend": cohend_xg,
    }
    
    # Append the result to the results list
    results_stat = pd.concat([results_stat, pd.DataFrame([result])], ignore_index=True)

# %% [markdown]
# #### EPL

# %%
dataframes = {
    # EPL
    2014: df_epl_2014,
    2015: df_epl_2015,
    2016: df_epl_2016,
    2017: df_epl_2017,
    2018: df_epl_2018,
    2019: df_epl_2019,
    2020: df_epl_2020,
    2021: df_epl_2021,
    2022: df_epl_2022,
    2023: df_epl_2023,
}

# %%
for season, df in dataframes.items():
    # Filter data for home and away games
    home_pts = df[df['h_a'] == 'h']['pts']
    away_pts = df[df['h_a'] == 'a']['pts']
    home_xpts = df[df['h_a'] == 'h']['xpts']
    away_xpts = df[df['h_a'] == 'a']['xpts']
    home_xg = df[df['h_a'] == 'h']['xG']
    away_xg = df[df['h_a'] == 'a']['xG']
    
    # Perform Wilcoxon Signed-Rank tests
    wilco_result = stats.wilcoxon(home_pts, away_pts, alternative='two-sided')
    wilco_xpts = stats.wilcoxon(home_xpts, away_xpts, alternative='two-sided')
    wilco_xg = stats.wilcoxon(home_xg, away_xg, alternative='two-sided')
    
    # Calculate Cohen's d for each metric
    cohend_result = (home_pts.mean() - away_pts.mean()) / np.sqrt((home_pts.std() ** 2 + away_pts.std() ** 2) / 2)
    cohend_xpts = (home_xpts.mean() - away_xpts.mean()) / np.sqrt((home_xpts.std() ** 2 + away_xpts.std() ** 2) / 2)
    cohend_xg = (home_xg.mean() - away_xg.mean()) / np.sqrt((home_xg.std() ** 2 + away_xg.std() ** 2) / 2)
    
    # Store results in a dictionary
    result = {
        "league": "EPL",
        "season": season,
        "wilco-result": wilco_result.statistic,
        "wilco-result-pvalue": wilco_result.pvalue,
        "result-cohend": cohend_result,
        "wilco-xPoints": wilco_xpts.statistic,
        "wilco-xPoints-pvalue": wilco_xpts.pvalue,
        "xPoints-cohend": cohend_xpts,
        "wilco-xG": wilco_xg.statistic,
        "wilco-xG-pvalue": wilco_xg.pvalue,
        "xG-cohend": cohend_xg,
    }
    
    # Append the result to the results list
    results_stat = pd.concat([results_stat, pd.DataFrame([result])], ignore_index=True)

# %% [markdown]
# #### Bundesliga

# %%
dataframes = {
    # Bundesliga
    2014: df_bundesliga_2014,
    2015: df_bundesliga_2015,
    2016: df_bundesliga_2016,
    2017: df_bundesliga_2017,
    2018: df_bundesliga_2018,
    2019: df_bundesliga_2019,
    2020: df_bundesliga_2020,
    2021: df_bundesliga_2021,
    2022: df_bundesliga_2022,
    2023: df_bundesliga_2023,
}

# %%
for season, df in dataframes.items():
    # Filter data for home and away games
    home_pts = df[df['h_a'] == 'h']['pts']
    away_pts = df[df['h_a'] == 'a']['pts']
    home_xpts = df[df['h_a'] == 'h']['xpts']
    away_xpts = df[df['h_a'] == 'a']['xpts']
    home_xg = df[df['h_a'] == 'h']['xG']
    away_xg = df[df['h_a'] == 'a']['xG']
    
    # Perform Wilcoxon Signed-Rank tests
    wilco_result = stats.wilcoxon(home_pts, away_pts, alternative='two-sided')
    wilco_xpts = stats.wilcoxon(home_xpts, away_xpts, alternative='two-sided')
    wilco_xg = stats.wilcoxon(home_xg, away_xg, alternative='two-sided')
    
    # Calculate Cohen's d for each metric
    cohend_result = (home_pts.mean() - away_pts.mean()) / np.sqrt((home_pts.std() ** 2 + away_pts.std() ** 2) / 2)
    cohend_xpts = (home_xpts.mean() - away_xpts.mean()) / np.sqrt((home_xpts.std() ** 2 + away_xpts.std() ** 2) / 2)
    cohend_xg = (home_xg.mean() - away_xg.mean()) / np.sqrt((home_xg.std() ** 2 + away_xg.std() ** 2) / 2)
    
    # Store results in a dictionary
    result = {
        "league": "Bundesliga",
        "season": season,
        "wilco-result": wilco_result.statistic,
        "wilco-result-pvalue": wilco_result.pvalue,
        "result-cohend": cohend_result,
        "wilco-xPoints": wilco_xpts.statistic,
        "wilco-xPoints-pvalue": wilco_xpts.pvalue,
        "xPoints-cohend": cohend_xpts,
        "wilco-xG": wilco_xg.statistic,
        "wilco-xG-pvalue": wilco_xg.pvalue,
        "xG-cohend": cohend_xg,
    }
    
    # Append the result to the results list
    results_stat = pd.concat([results_stat, pd.DataFrame([result])], ignore_index=True)

# %% [markdown]
# #### Serie A

# %%
dataframes = {
    # Serie A
    2014: df_seriea_2014,
    2015: df_seriea_2015,
    2016: df_seriea_2016,
    2017: df_seriea_2017,
    2018: df_seriea_2018,
    2019: df_seriea_2019,
    2020: df_seriea_2020,
    2021: df_seriea_2021,
    2022: df_seriea_2022,
    2023: df_seriea_2023,
}

# %%
for season, df in dataframes.items():
    # Filter data for home and away games
    home_pts = df[df['h_a'] == 'h']['pts']
    away_pts = df[df['h_a'] == 'a']['pts']
    home_xpts = df[df['h_a'] == 'h']['xpts']
    away_xpts = df[df['h_a'] == 'a']['xpts']
    home_xg = df[df['h_a'] == 'h']['xG']
    away_xg = df[df['h_a'] == 'a']['xG']
    
    # Perform Wilcoxon Signed-Rank tests
    wilco_result = stats.wilcoxon(home_pts, away_pts, alternative='two-sided')
    wilco_xpts = stats.wilcoxon(home_xpts, away_xpts, alternative='two-sided')
    wilco_xg = stats.wilcoxon(home_xg, away_xg, alternative='two-sided')
    
    # Calculate Cohen's d for each metric
    cohend_result = (home_pts.mean() - away_pts.mean()) / np.sqrt((home_pts.std() ** 2 + away_pts.std() ** 2) / 2)
    cohend_xpts = (home_xpts.mean() - away_xpts.mean()) / np.sqrt((home_xpts.std() ** 2 + away_xpts.std() ** 2) / 2)
    cohend_xg = (home_xg.mean() - away_xg.mean()) / np.sqrt((home_xg.std() ** 2 + away_xg.std() ** 2) / 2)
    
    # Store results in a dictionary
    result = {
        "league": "Serie_A",
        "season": season,
        "wilco-result": wilco_result.statistic,
        "wilco-result-pvalue": wilco_result.pvalue,
        "result-cohend": cohend_result,
        "wilco-xPoints": wilco_xpts.statistic,
        "wilco-xPoints-pvalue": wilco_xpts.pvalue,
        "xPoints-cohend": cohend_xpts,
        "wilco-xG": wilco_xg.statistic,
        "wilco-xG-pvalue": wilco_xg.pvalue,
        "xG-cohend": cohend_xg,
    }
    
    # Append the result to the results list
    results_stat = pd.concat([results_stat, pd.DataFrame([result])], ignore_index=True)

# %% [markdown]
# #### RFPL

# %%
dataframes = {
    # RFPL
    2014: df_rfpl_2014,
    2015: df_rfpl_2015,
    2016: df_rfpl_2016,
    2017: df_rfpl_2017,
    2018: df_rfpl_2018,
    2019: df_rfpl_2019,
    2020: df_rfpl_2020,
    2021: df_rfpl_2021,
    2022: df_rfpl_2022,
    2023: df_rfpl_2023
}

# %%
for season, df in dataframes.items():
    # Filter data for home and away games
    home_pts = df[df['h_a'] == 'h']['pts']
    away_pts = df[df['h_a'] == 'a']['pts']
    home_xpts = df[df['h_a'] == 'h']['xpts']
    away_xpts = df[df['h_a'] == 'a']['xpts']
    home_xg = df[df['h_a'] == 'h']['xG']
    away_xg = df[df['h_a'] == 'a']['xG']
    
    # Perform Wilcoxon Signed-Rank tests
    wilco_result = stats.wilcoxon(home_pts, away_pts, alternative='two-sided')
    wilco_xpts = stats.wilcoxon(home_xpts, away_xpts, alternative='two-sided')
    wilco_xg = stats.wilcoxon(home_xg, away_xg, alternative='two-sided')
    
    # Calculate Cohen's d for each metric
    cohend_result = (home_pts.mean() - away_pts.mean()) / np.sqrt((home_pts.std() ** 2 + away_pts.std() ** 2) / 2)
    cohend_xpts = (home_xpts.mean() - away_xpts.mean()) / np.sqrt((home_xpts.std() ** 2 + away_xpts.std() ** 2) / 2)
    cohend_xg = (home_xg.mean() - away_xg.mean()) / np.sqrt((home_xg.std() ** 2 + away_xg.std() ** 2) / 2)
    
    # Store results in a dictionary
    result = {
        "league": "RFPL",
        "season": season,
        "wilco-result": wilco_result.statistic,
        "wilco-result-pvalue": wilco_result.pvalue,
        "result-cohend": cohend_result,
        "wilco-xPoints": wilco_xpts.statistic,
        "wilco-xPoints-pvalue": wilco_xpts.pvalue,
        "xPoints-cohend": cohend_xpts,
        "wilco-xG": wilco_xg.statistic,
        "wilco-xG-pvalue": wilco_xg.pvalue,
        "xG-cohend": cohend_xg,
    }
    
    # Append the result to the results list
    results_stat = pd.concat([results_stat, pd.DataFrame([result])], ignore_index=True)

# %%
def highlight_pvalues(val):
    try:
        if pd.notna(val) and float(val) >= 0.05:
            return 'color: red;'  # Highlight significant p-values in red
    except ValueError:
        pass
    return ''

# Create a function to style effect sizes (Cohen's d)
def highlight_effect_size(val):
    try:
        val = float(val)
        if val < 0.20:  # Small effect size
            return 'background-color: yellow;'
    except ValueError:
        pass
    return ''

# %%
styled_results_stat = results_stat.style.applymap(highlight_pvalues, subset=[
    'wilco-result-pvalue', 'wilco-xPoints-pvalue', 'wilco-xG-pvalue'
]).applymap(highlight_effect_size, subset=[
    'result-cohend', 'xPoints-cohend', 'xG-cohend'
])
# Out:
# C:\Users\ezgi\AppData\Local\Temp\ipykernel_54868\1297101725.py:1: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   styled_results_stat = results_stat.style.applymap(highlight_pvalues, subset=[
# C:\Users\ezgi\AppData\Local\Temp\ipykernel_54868\1297101725.py:3: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   ]).applymap(highlight_effect_size, subset=[

# %%
styled_results_stat
# Out:
# <style type="text/css">
# #T_b07df_row6_col3, #T_b07df_row9_col3, #T_b07df_row26_col3, #T_b07df_row26_col9, #T_b07df_row35_col3, #T_b07df_row45_col3, #T_b07df_row47_col3, #T_b07df_row55_col3 {
#   color: red;
# }
# #T_b07df_row6_col4, #T_b07df_row6_col7, #T_b07df_row6_col10, #T_b07df_row9_col4, #T_b07df_row26_col4, #T_b07df_row26_col7, #T_b07df_row26_col10, #T_b07df_row35_col4, #T_b07df_row35_col10, #T_b07df_row43_col4, #T_b07df_row45_col4, #T_b07df_row46_col4, #T_b07df_row46_col10, #T_b07df_row47_col4, #T_b07df_row55_col4 {
#   background-color: yellow;
# }
# </style>
# <table id="T_b07df">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b07df_level0_col0" class="col_heading level0 col0" >league</th>
#       <th id="T_b07df_level0_col1" class="col_heading level0 col1" >season</th>
#       <th id="T_b07df_level0_col2" class="col_heading level0 col2" >wilco-result</th>
#       <th id="T_b07df_level0_col3" class="col_heading level0 col3" >wilco-result-pvalue</th>
#       <th id="T_b07df_level0_col4" class="col_heading level0 col4" >result-cohend</th>
#       <th id="T_b07df_level0_col5" class="col_heading level0 col5" >wilco-xPoints</th>
#       <th id="T_b07df_level0_col6" class="col_heading level0 col6" >wilco-xPoints-pvalue</th>
#       <th id="T_b07df_level0_col7" class="col_heading level0 col7" >xPoints-cohend</th>
#       <th id="T_b07df_level0_col8" class="col_heading level0 col8" >wilco-xG</th>
#       <th id="T_b07df_level0_col9" class="col_heading level0 col9" >wilco-xG-pvalue</th>
#       <th id="T_b07df_level0_col10" class="col_heading level0 col10" >xG-cohend</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b07df_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b07df_row0_col0" class="data row0 col0" >Ligue_1</td>
#       <td id="T_b07df_row0_col1" class="data row0 col1" >2014</td>
#       <td id="T_b07df_row0_col2" class="data row0 col2" >10430.000000</td>
#       <td id="T_b07df_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_b07df_row0_col4" class="data row0 col4" >0.423654</td>
#       <td id="T_b07df_row0_col5" class="data row0 col5" >19144.000000</td>
#       <td id="T_b07df_row0_col6" class="data row0 col6" >0.000000</td>
#       <td id="T_b07df_row0_col7" class="data row0 col7" >0.592618</td>
#       <td id="T_b07df_row0_col8" class="data row0 col8" >23087.000000</td>
#       <td id="T_b07df_row0_col9" class="data row0 col9" >0.000000</td>
#       <td id="T_b07df_row0_col10" class="data row0 col10" >0.428402</td>
#     </tr>
#     <tr>
#       <th id="T_b07df_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b07df_row1_col0" class="data row1 col0" >Ligue_1</td>
#       <td id="T_b07df_row1_col1" class="data row1 col1" >2015</td>
#       <td id="T_b07df_row1_col2" class="data row1 col2" >8765.000000</td>
#       <td id="T_b07df_row1_col3" class="data row1 col3" >0.000009</td>
#       <td id="T_b07df_row1_col4" class="data row1 col4" >0.296835</td>
#       <td id="T_b07df_row1_col5" class="data row1 col5" >16363.500000</td>
#       <td id="T_b07df_row1_col6" class="data row1 col6" >0.000000</td>
#       <td id="T_b07df_row1_col7" class="data row1 col7" >0.665501</td>
#       <td id="T_b07df_row1_col8" class="data row1 col8" >21230.000000</td>
#       <td id="T_b07df_row1_col9" class="data row1 col9" >0.000000</td>
#       <td id="T_b07df_row1_col10" class="data row1 col10" >0.484468</td>
#     </tr>
#     <tr>
#       <th id="T_b07df_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b07df_row2_col0" class="data row2 col0" >Ligue_1</td>
#       <td id="T_b07df_row2_col1" class="data row2 col1" >2016</td>
#       <td id="T_b07df_row2_col2" class="data row2 col2" >8413.000000</td>
#       <td id="T_b07df_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_b07df_row2_col4" class="data row2 col4" >0.531954</td>
#       <td id="T_b07df_row2_col5" class="data row2 col5" >17052.500000</td>
#       <td id="T_b07df_row2_col6" class="data row2 col6" >0.000000</td>
#       <td id="T_b07df_row2_col7" class="data row2 col7" >0.676671</td>
#       <td id="T_b07df_row2_col8" class="data row2 col8" >21441.000000</td>
#       <td id="T_b07df_row2_col9" class="data row2 col9" >0.000000</td>
#       <td id="T_b07df_row2_col10" class="data row2 col10" >0.479961</td>
#     </tr>
#     <tr>
#       <th id="T_b07df_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b07df_row3_col0" class="data row3 col0" >Ligue_1</td>
#       <td id="T_b07df_row3_col1" class="data row3 col1" >2017</td>
#       <td id="T_b07df_row3_col2" class="data row3 col2" >7391.000000</td>
#       <td id="T_b07df_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_b07df_row3_col4" class="data row3 col4" >0.378394</td>
#       <td id="T_b07df_row3_col5" class="data row3 col5" >18828.500000</td>
#       <td id="T_b07df_row3_col6" class="data row3 col6" >0.000000</td>
#       <td id="T_b07df_row3_col7" class="data row3 col7" >0.576631</td>
#       <td id="T_b07df_row3_col8" class="data row3 col8" >22750.000000</td>
#       <td id="T_b07df_row3_col9" class="data row3 col9" >0.000000</td>
#       <td id="T_b07df_row3_col10" class="data row3 col10" >0.439724</td>
#     </tr>
#     <tr>
#       <th id="T_b07df_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b07df_row4_col0" class="data row4 col0" >Ligue_1</td>
#       <td id="T_b07df_row4_col1" class="data row4 col1" >2018</td>
#       <td id="T_b07df_row4_col2" class="data row4 col2" >7785.000000</td>
#       <td id="T_b07df_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_b07df_row4_col4" class="data row4 col4" >0.361783</td>
#       <td id="T_b07df_row4_col5" class="data row4 col5" >19937.000000</td>
#       <td id="T_b07df_row4_col6" class="data row4 col6" >0.000000</td>
#       <td id="T_b07df_row4_col7" class="data row4 col7" >0.578288</td>
#       <td id="T_b07df_row4_col8" class="data row4 col8" >21101.000000</td>
#       <td id="T_b07df_row4_col9" class="data row4 col9" >0.000000</td>
#       <td id="T_b07df_row4_col10" class="data row4 col10" >0.444494</td>
#     </tr>
#     <tr>
#       <th id="T_b07df_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b07df_row5_col0" class="data row5 col0" >Ligue_1</td>
#       <td id="T_b07df_row5_col1" class="data row5 col1" >2019</td>
#       <td id="T_b07df_row5_col2" class="data row5 col2" >3815.500000</td>
#       <td id="T_b07df_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_b07df_row5_col4" class="data row5 col4" >0.495734</td>
#       <td id="T_b07df_row5_col5" class="data row5 col5" >10871.000000</td>
#       <td id="T_b07df_row5_col6" class="data row5 col6" >0.000000</td>
#       <td id="T_b07df_row5_col7" class="data row5 col7" >0.558692</td>
#       <td id="T_b07df_row5_col8" class="data row5 col8" >12409.000000</td>
#       <td id="T_b07df_row5_col9" class="data row5 col9" >0.000000</td>
#       <td id="T_b07df_row5_col10" class="data row5 col10" >0.440770</td>
#     </tr>
#     <tr>
#       <th id="T_b07df_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b07df_row6_col0" class="data row6 col0" >Ligue_1</td>
#       <td id="T_b07df_row6_col1" class="data row6 col1" >2020</td>
#       <td id="T_b07df_row6_col2" class="data row6 col2" >15212.500000</td>
#       <td id="T_b07df_row6_col3" class="data row6 col3" >0.927026</td>
#       <td id="T_b07df_row6_col4" class="data row6 col4" >-0.005987</td>
#       <td id="T_b07df_row6_col5" class="data row6 col5" >30974.000000</td>
#       <td id="T_b07df_row6_col6" class="data row6 col6" >0.014820</td>
#       <td id="T_b07df_row6_col7" class="data row6 col7" >0.191954</td>
#       <td id="T_b07df_row6_col8" class="data row6 col8" >31832.000000</td>
#       <td id="T_b07df_row6_col9" class="data row6 col9" >0.041719</td>
#       <td id="T_b07df_row6_col10" class="data row6 col10" >0.190976</td>
#     </tr>
#     <tr>
#       <th id="T_b07df_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b07df_row7_col0" class="data row7 col0" >Ligue_1</td>
#       <td id="T_b07df_row7_col1" c

# %% [markdown]
# The results confirm that **COVID and the absence of crowds disrupted home advantage across all leagues**. While there has been some recovery post-COVID, the extent varies:
# - **EPL:** Near-complete recovery.
# - **Bundesliga, Ligue 1, RFPL:** Partial or incomplete recovery, with lingering reductions in home advantage.
#
# The combination of Wilcoxon p-values and Cohen’s d effect sizes provides robust evidence of these shifts, emphasizing the role of external factors like crowd support in shaping football outcomes.

# %% [markdown]
# ## Champions League Data as a Variability Factor

# %% [markdown]
# For a second variability factor, we decided to pull Champions League matches data from *stathead.com*. This dataset covers **pre-COVID seasons (2017–2019)**, the **COVID-impacted season (2019–2020)** with no fans, and **post-COVID seasons (2021–2023)** with varying levels of recovery in crowd attendance and team dynamics.
#
# Analyzing the 2017–2023 Champions League seasons introduces a valuable variability factor by leveraging the unique features of this international competition. It allows us to:
# 1. Test the robustness of home/away dynamics across a wide range of teams, venues, and contexts.
# 2. Evaluate the impact of global events (like COVID) and high-pressure match contexts on the original findings.
# 3. Strengthen the conclusions of the replication by demonstrating whether the results generalize beyond domestic leagues to elite international football.
#
# This dataset provides a rich testing ground for exploring variability while maintaining relevance to the original study.

# %% [markdown]
# ### Importing and Cleaning Champions Lague Data

# %%
df = pd.read_csv("database_ucl_stathead.csv")
df
# Out:
#         Rk                Team        Date   xG  h_a                 Opp  \
# 0        1         de Dortmund  2024-06-01  2.1  NaN      es Real Madrid
# 1        2      es Real Madrid  2024-06-01  1.1    @         de Dortmund
# 2        3    de Bayern Munich  2024-05-08  0.4    @      es Real Madrid
# 3        4      es Real Madrid  2024-05-08  2.8  NaN    de Bayern Munich
# 4        5        fr Paris S-G  2024-05-07  3.0  NaN         de Dortmund
# ...    ...                 ...         ...  ...  ...                 ...
# 1733  1734            ch Basel  2017-09-12  0.6    @  eng Manchester Utd
# 1734  1735  es Atlético Madrid  2017-09-12  2.4    @             it Roma
# 1735  1736         it Juventus  2017-09-12  0.7    @        es Barcelona
# 1736  1737        fr Paris S-G  2017-09-12  2.5    @          sct Celtic
# 1737  1738      ru CSKA Moscow  2017-09-12  1.6    @          pt Benfica
#
#                   Comp              Round TieRslt Result  ...  A-xAG  npxG/Sh  \
# 0     Champions League              Final     NaN  L 0-2  ...   -1.2     0.17
# 1     Champions League              Final     NaN  W 2-0  ...    1.1     0.09
# 2     Champions League  Semi-finals Leg 2   L 3-4  L 1-2  ...    0.8     0.04
# 3     Champions League  Semi-finals Leg 2   W 4-3  W 2-1  ...   -0.7     0.16
# 4     Champions League  Semi-finals Leg 2   L 0-2  L 0-1  ...   -2.4     0.11
# ...                ...                ...     ...    ...  ...    ...      ...
# 1733  Champions League              Group     NaN  L 0-3  ...   -0.5     0.07
# 1734  Champions League              Group     NaN  D 0-0  ...   -1.8     0.13
# 1735  Champions League              Group     NaN  L 0-3  ...   -0.5     0.05
# 1736  Champions League              Group     NaN  W 5-0  ...    1.2     0.20
# 1737  Champions League              Group     NaN  W 2-1  ...   -0.5     0.08
#
#       Sh  G/Sh  G/SoT  SoT  SoT%  Dist  FK  Match Report
# 0     13  0.00   0.00    3  23.1  16.2   0  Match Report
# 1     13  0.15   0.33    6  46.2  17.1   2  Match Report
# 2      8  0.13   0.20    5  62.5  17.4   0  Match Report
# 3     19  0.11   0.29    7  36.8  17.6   1  Match Report
# 4     30  0.00   0.00    5  16.7  17.5   1  Match Report
# ...   ..   ...    ...  ...   ...   ...  ..           ...
# 1733   8  0.00   0.00    2  25.0  19.5   0  Match Report
# 1734  20  0.00   0.00    9  45.0  20.3   1  Match Report
# 1735  13  0.00   0.00    6  46.2  20.0   0  Match Report
# 1736   9  0.33   0.60    5  55.6  16.9   0  Match Report
# 1737  13  0.08   0.17    6  46.2  19.1   0  Match Report
#
# [1738 rows x 36 columns]

# %%
count_at = df['h_a'].value_counts().get('@', 0)

# Display the result
print(f"The number of occurrences of '@' in the 'h_a' column is: {count_at}")
# Out:
# The number of occurrences of '@' in the 'h_a' column is: 855

# %%
# Function to extract the season based on the date string
def assign_season_from_string(date_str):
    if pd.isna(date_str):
        return None  # Handle missing dates explicitly
    # Extract year and month from the date string
    year = int(date_str[:4])  # First 4 characters represent the year
    month = int(date_str[5:7])  # Characters 5-7 represent the month
    if month >= 9:  # Matches between September and December belong to the current year
        return year
    elif month <= 8:  # Matches between January and August belong to the previous year
        return year - 1
    else:
        return None  # This should not occur

# %%
# Function to clean and transform the DataFrame
def new_dataframe(df): 
    # Rename the 'Team' column to 'team_name'
    df.rename(columns={"Team": "team_name"}, inplace=True)
    df.rename(columns={"Round": "match_round"}, inplace=True)
    
    # Update 'h_a' column logic
    df['h_a'] = df['h_a'].apply(lambda x: 'h' if pd.isna(x) else 'a')

    # Extract the season from the 'Date' column (kept as string)
    df['season'] = df['Date'].apply(assign_season_from_string)
    df = df[df['season'].notna()]  # Filter out rows with missing seasons
    df['season'] = df['season'].astype(int)  # Ensure 'season' is an integer

    # Keep only the necessary columns
    columns_to_keep = ['team_name', 'season', 'h_a', 'xG', 'match_round', 'GF', 'GA', 'GD']
    df = df[columns_to_keep]
    
    return df

# %%
df_ucl = new_dataframe(df)
df_ucl.head()
# Out:
#           team_name  season h_a   xG        match_round  GF  GA  GD
# 0       de Dortmund    2023   h  2.1              Final   0   2  -2
# 1    es Real Madrid    2023   a  1.1              Final   2   0   2
# 2  de Bayern Munich    2023   a  0.4  Semi-finals Leg 2   1   2  -1
# 3    es Real Madrid    2023   h  2.8  Semi-finals Leg 2   2   1   1
# 4      fr Paris S-G    2023   h  3.0  Semi-finals Leg 2   0   1  -1

# %% [markdown]
# ### Table with bar charts to visualize and investigate a possible effect of COVID on home advantage

# %%
# Function to calculate grouped results
def calculate_seasonal_sums(df):
    # Group by season and calculate the sums
    grouped = df.groupby('season').apply(lambda group: pd.Series({
        'sum_points_away': group.loc[group['h_a'] == 'a', 'GF'].sum(),  # Sum of GF where h_a == 'a'
        'sum_points_home': group.loc[group['h_a'] == 'h', 'GF'].sum(),  # Sum of GF where h_a == 'h'
        'sum_xG_away': group.loc[group['h_a'] == 'a', 'xG'].sum(),      # Sum of xG where h_a == 'a'
        'sum_xG_home': group.loc[group['h_a'] == 'h', 'xG'].sum(),      # Sum of xG where h_a == 'h'
        'avg_points_away':  group.loc[group['h_a'] == 'a', 'GF'].mean(),
        'avg_points_home':  group.loc[group['h_a'] == 'h', 'GF'].mean(),
        'avg_xG_away': group.loc[group['h_a'] == 'a', 'xG'].mean(),      # Sum of xG where h_a == 'a'
        'avg_xG_home': group.loc[group['h_a'] == 'h', 'xG'].mean()
    })).reset_index()

    return grouped

# %%
results = calculate_seasonal_sums(df_ucl)

# %%
diff_results = pd.DataFrame({
    "LEAGUE": 'Champions League',
    "YEAR": results["season"],      # Keep the year column
    "DIFF_POINTS_HOMEAWAY": (results["sum_points_home"] - results["sum_points_away"]).round(0).astype(int),  # Calculate points difference
})

# %%
styled_df = diff_results.style.bar(
    subset=["DIFF_POINTS_HOMEAWAY"], 
    color=['lightcoral', 'mediumseagreen'], 
    align='zero'  # Aligns negative bars to the left
)
styled_df
# Out:
# <style type="text/css">
# #T_83353_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, mediumseagreen 50.0%, mediumseagreen 83.6%, transparent 83.6%);
# }
# #T_83353_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, mediumseagreen 50.0%, mediumseagreen 100.0%, transparent 100.0%);
# }
# #T_83353_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 48.3%, lightcoral 48.3%, lightcoral 50.0%, transparent 50.0%);
# }
# #T_83353_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 43.1%, lightcoral 43.1%, lightcoral 50.0%, transparent 50.0%);
# }
# #T_83353_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, mediumseagreen 50.0%, mediumseagreen 64.7%, transparent 64.7%);
# }
# #T_83353_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, mediumseagreen 50.0%, mediumseagreen 80.2%, transparent 80.2%);
# }
# #T_83353_row6_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, mediumseagreen 50.0%, mediumseagreen 98.3%, transparent 98.3%);
# }
# </style>
# <table id="T_83353">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_83353_level0_col0" class="col_heading level0 col0" >LEAGUE</th>
#       <th id="T_83353_level0_col1" class="col_heading level0 col1" >YEAR</th>
#       <th id="T_83353_level0_col2" class="col_heading level0 col2" >DIFF_POINTS_HOMEAWAY</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_83353_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_83353_row0_col0" class="data row0 col0" >Champions League</td>
#       <td id="T_83353_row0_col1" class="data row0 col1" >2017</td>
#       <td id="T_83353_row0_col2" class="data row0 col2" >39</td>
#     </tr>
#     <tr>
#       <th id="T_83353_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_83353_row1_col0" class="data row1 col0" >Champions League</td>
#       <td id="T_83353_row1_col1" class="data row1 col1" >2018</td>
#       <td id="T_83353_row1_col2" class="data row1 col2" >58</td>
#     </tr>
#     <tr>
#       <th id="T_83353_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_83353_row2_col0" class="data row2 col0" >Champions League</td>
#       <td id="T_83353_row2_col1" class="data row2 col1" >2019</td>
#       <td id="T_83353_row2_col2" class="data row2 col2" >-2</td>
#     </tr>
#     <tr>
#       <th id="T_83353_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_83353_row3_col0" class="data row3 col0" >Champions League</td>
#       <td id="T_83353_row3_col1" class="data row3 col1" >2020</td>
#       <td id="T_83353_row3_col2" class="data row3 col2" >-8</td>
#     </tr>
#     <tr>
#       <th id="T_83353_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_83353_row4_col0" class="data row4 col0" >Champions League</td>
#       <td id="T_83353_row4_col1" class="data row4 col1" >2021</td>
#       <td id="T_83353_row4_col2" class="data row4 col2" >17</td>
#     </tr>
#     <tr>
#       <th id="T_83353_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_83353_row5_col0" class="data row5 col0" >Champions League</td>
#       <td id="T_83353_row5_col1" class="data row5 col1" >2022</td>
#       <td id="T_83353_row5_col2" class="data row5 col2" >35</td>
#     </tr>
#     <tr>
#       <th id="T_83353_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_83353_row6_col0" class="data row6 col0" >Champions League</td>
#       <td id="T_83353_row6_col1" class="data row6 col1" >2023</td>
#       <td id="T_83353_row6_col2" class="data row6 col2" >56</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# We can see that even though the tournament features top teams from across Europe with varying tactical styles, squad depth, and historical dominance and  different pressures and higher stakes than the national football competitions, we can still see that home advantage diminished significantly during the COVID season (between 2019 and 2020). We can put forward the hypothesis that the reason for this is the absence of crowds. Home advantage is often considered more pronounced in international tournaments due to long-distance travel, unfamiliar environments, and crowd hostility.

# %%
diff_results = pd.DataFrame({
    "LEAGUE": 'Champions League',
    "YEAR": results["season"],      # Keep the year column
    "DIFF_XG_HOMEAWAY": (results["sum_xG_home"] - results["sum_xG_away"]).round(0).astype(int),  # Calculate points difference
})

# %%
styled_df = diff_results.style.bar(
    subset=["DIFF_XG_HOMEAWAY"], 
    color=['lightcoral', 'mediumseagreen'], 
    align='zero'  # Aligns negative bars to the left
)
styled_df
# Out:
# <style type="text/css">
# #T_81676_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, mediumseagreen 50.0%, mediumseagreen 86.7%, transparent 86.7%);
# }
# #T_81676_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, mediumseagreen 50.0%, mediumseagreen 100.0%, transparent 100.0%);
# }
# #T_81676_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, mediumseagreen 50.0%, mediumseagreen 64.3%, transparent 64.3%);
# }
# #T_81676_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, mediumseagreen 50.0%, mediumseagreen 54.1%, transparent 54.1%);
# }
# #T_81676_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, mediumseagreen 50.0%, mediumseagreen 61.2%, transparent 61.2%);
# }
# #T_81676_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, mediumseagreen 50.0%, mediumseagreen 82.7%, transparent 82.7%);
# }
# #T_81676_row6_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, mediumseagreen 50.0%, mediumseagreen 96.9%, transparent 96.9%);
# }
# </style>
# <table id="T_81676">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_81676_level0_col0" class="col_heading level0 col0" >LEAGUE</th>
#       <th id="T_81676_level0_col1" class="col_heading level0 col1" >YEAR</th>
#       <th id="T_81676_level0_col2" class="col_heading level0 col2" >DIFF_XG_HOMEAWAY</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_81676_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_81676_row0_col0" class="data row0 col0" >Champions League</td>
#       <td id="T_81676_row0_col1" class="data row0 col1" >2017</td>
#       <td id="T_81676_row0_col2" class="data row0 col2" >36</td>
#     </tr>
#     <tr>
#       <th id="T_81676_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_81676_row1_col0" class="data row1 col0" >Champions League</td>
#       <td id="T_81676_row1_col1" class="data row1 col1" >2018</td>
#       <td id="T_81676_row1_col2" class="data row1 col2" >49</td>
#     </tr>
#     <tr>
#       <th id="T_81676_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_81676_row2_col0" class="data row2 col0" >Champions League</td>
#       <td id="T_81676_row2_col1" class="data row2 col1" >2019</td>
#       <td id="T_81676_row2_col2" class="data row2 col2" >14</td>
#     </tr>
#     <tr>
#       <th id="T_81676_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_81676_row3_col0" class="data row3 col0" >Champions League</td>
#       <td id="T_81676_row3_col1" class="data row3 col1" >2020</td>
#       <td id="T_81676_row3_col2" class="data row3 col2" >4</td>
#     </tr>
#     <tr>
#       <th id="T_81676_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_81676_row4_col0" class="data row4 col0" >Champions League</td>
#       <td id="T_81676_row4_col1" class="data row4 col1" >2021</td>
#       <td id="T_81676_row4_col2" class="data row4 col2" >11</td>
#     </tr>
#     <tr>
#       <th id="T_81676_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_81676_row5_col0" class="data row5 col0" >Champions League</td>
#       <td id="T_81676_row5_col1" class="data row5 col1" >2022</td>
#       <td id="T_81676_row5_col2" class="data row5 col2" >32</td>
#     </tr>
#     <tr>
#       <th id="T_81676_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_81676_row6_col0" class="data row6 col0" >Champions League</td>
#       <td id="T_81676_row6_col1" class="data row6 col1" >2023</td>
#       <td id="T_81676_row6_col2" class="data row6 col2" >46</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Plot of evolution of mean gained points (per match)

# %%
plt.plot(results['season'], results['avg_points_home'], marker='o', label='result_home')
plt.plot(results['season'], results['avg_points_away'], marker='o', label='result_away')
plt.xlabel('seasons')
plt.ylabel('mean gained points per match')
plt.title('Champions League')
plt.legend()
plt.show()

# %% [markdown]
# The graph clearly shows how the COVID-19 pandemic disrupted the traditional home advantage in the Champions League. While home performance has rebounded post-COVID, the gap between home and away points is approaching pre-pandemic levels, suggesting a gradual normalization of home advantage dynamics in the competition.

# %%
plt.plot(results['season'], results['avg_xG_home'], marker='o', label='xg_home')
plt.plot(results['season'], results['avg_xG_away'], marker='o', label='xg_away')
plt.xlabel('seasons')
plt.ylabel('mean xG per match')
plt.title('Champions League')
plt.legend()
plt.show()
